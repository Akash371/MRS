# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install anvil-uplink
# Out:
# Requirement already satisfied: anvil-uplink in /usr/local/lib/python3.7/dist-packages (0.3.42)
# Requirement already satisfied: ws4py in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (0.5.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (1.15.0)
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (0.16.0)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
import anvil.server

anvil.server.connect('P537IAVNEGB3GK7FM3VR6F5D-SZLOP5D5L6VYALHF')

# %%
# pip install tensorflow keras pickle nltk
from google.colab import drive
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('/content/drive/MyDrive/Colab Notebooks/intents.json').read()
intents = json.loads(intents_file)

# %%
import nltk
from nltk.chat.util import Chat, reflections
nltk.download('punkt')
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [(['hi'], 'greeting'), (['hello'], 'greeting'), (['whats', 'up'], 'greeting'), (['sup'], 'greeting'), (['is', 'anyone', 'there'], 'greeting'), (['whats', 'good'], 'greeting'), (['hey'], 'greeting'), (['bye'], 'goodbye'), (['cya'], 'goodbye'), (['see', 'you', 'later'], 'goodbye'), (['goodbye'], 'goodbye'), (['im', 'leaving'], 'goodbye'), (['have', 'a', 'good', 'day'], 'goodbye'), (['how', 'old', 'are', 'you'], 'age'), (['what', 'is', 'your', 'age'], 'age'), (['thanks'], 'thanks'), (['thank', 'you'], 'thanks'), (['thankyou'], 'thanks'), (['ty'], 'thanks'), (['I', 'owe', 'you', 'one'], 'thanks'), (['whats', 'is', 'your', 'name'], 'name'), (['whats', 'your', 'name'], 'name'), (['whats', 'should', 'I', 'call', 'you'], 'name'), (['how', 'should', 'I', 'address', 'you'], 'name'), (['Yes', 'it', 'does'], 'sky_net_yes'), (['Yeah'], 'sky_net_yes'), (['Haha', 'yep'], 'sky_net_yes'), (['yes'], 'sky_net_yes'), (['Indeed'], 'sky_net_yes'), (['Yup'], 'sky_net_yes'), (['Just', 'like', 'the', 'terminator'], 'sky_net_yes'), (['no'], 'sky_net_no'), (['nah'], 'sky_net_no'), (['not', 'really'], 'sky_net_no'), (['thats', 'scary'], 'sky_net_no'), (['singularity'], 'sky_net_no'), (['how', 'are', 'you'], 'how_are_you'), (['how', 'are', 'you', 'doing'], 'how_are_you'), (['what', 'is', 'going', 'on'], 'how_are_you'), (['I', 'am', 'doing', 'great'], 'doing_great'), (['I', 'am', 'well'], 'doing_great'), (['Im', 'great'], 'doing_great'), (['awesome'], 'doing_great'), (['happy'], 'doing_great'), (['better'], 'doing_great'), (['not', 'great'], 'doing_badly'), (['not', 'well'], 'doing_badly'), (['not', 'good'], 'doing_badly'), (['bad'], 'doing_badly'), (['badly'], 'doing_badly'), (['terrible'], 'doing_badly'), (['horrible'], 'doing_badly'), (['awful'], 'doing_badly'), (['sad'], 'doing_badly'), (['wait', 'you', 'watch', 'Netflix'], 'netflix'), (['how', 'do', 'you', 'watch', 'Netflix'], 'netflix'), (['Netflix'], 'netflix'), (['how', 'can', 'you', 'run'], 'quick_run'), (['how', 'do', 'you', 'run'], 'quick_run'), (['how', 'run'], 'quick_run'), (['why', 'run'], 'quick_run'), (['run'], 'quick_run'), (['you', 'real'], 'real_bot'), (['you', 'human'], 'real_bot'), (['you', 'robot'], 'real_bot'), (['you', 'alive'], 'real_bot'), (['you', 'sentient'], 'real_bot'), (['you', 'conscious'], 'real_bot'), (['tell', 'me', 'joke'], 'joke'), (['got', 'any', 'good', 'jokes'], 'joke'), (['got', 'jokes'], 'joke'), (['can', 'you', 'tell', 'joke'], 'joke'), (['tell', 'joke'], 'joke'), (['haha'], 'good_joke'), (['that', 'was', 'funny'], 'good_joke'), (['very', 'funny'], 'good_joke'), (['good', 'one'], 'good_joke'), (['bad', 'joke'], 'bad_joke'), (['trash', 'joke'], 'bad_joke'), (['terrible'], 'bad_joke'), (['not', 'funny'], 'bad_joke'), (['I', 'hate', 'you'], 'hate'), (['you', 'stupid'], 'hate'), (['you', 'dumb'], 'hate'), (['you', 'mean'], 'hate'), (['you', 'my', 'friend'], 'like'), (['I', 'like', 'you'], 'like'), (['I', 'love', 'you'], 'like'), (['you', 'cool'], 'like'), (['you', 'are', 'chill'], 'like'), (['whats', 'favorite', 'show'], 'favorite_show'), (['favorite', 'tv', 'show'], 'favorite_show'), (['Whats', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'film'], 'favorite_movie'), (['best', 'movie'], 'favorite_movie'), (['your', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'movie'], 'favorite_movie'), (['What', 'think', 'about'], 'your_thoughts'), (['What', 'your', 'thoughts'], 'your_thoughts')]

# %%
import nltk
nltk.download('wordnet')
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words

    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Training data is created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0319 - accuracy: 0.0707
# Epoch 2/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3.0189 - accuracy: 0.0707
# Epoch 3/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.8046 - accuracy: 0.2121
# Epoch 4/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.7465 - accuracy: 0.2323
# Epoch 5/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.5730 - accuracy: 0.2626
# Epoch 6/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.5253 - accuracy: 0.2525
# Epoch 7/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.4939 - accuracy: 0.2020
# Epoch 8/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.2936 - accuracy: 0.3030
# Epoch 9/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.2043 - accuracy: 0.2727
# Epoch 10/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2.0804 - accuracy: 0.3333
# Epoch 11/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9895 - accuracy: 0.3535
# Epoch 12/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8920 - accuracy: 0.3737
# Epoch 13/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9879 - accuracy: 0.3232
# Epoch 14/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8780 - accuracy: 0.4343
# Epoch 15/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7010 - accuracy: 0.3838
# Epoch 16/200
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8083 - accuracy: 0.4545
# Epoch 17/200
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5837 - accuracy: 0.5051
# Epoch 18/200
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5935 - accuracy: 0.4848
# Epoch 19/200
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6349 - accuracy: 0.4949
# Epoch 20/200
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6374 - accuracy: 0.5051
# Epoch 21/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5669 - accuracy: 0.5152
# Epoch 22/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5708 - accuracy: 0.4242
# Epoch 23/200
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4253 - accuracy: 0.5051
# Epoch 24/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4091 - accuracy: 0.5556
# Epoch 25/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4853 - accuracy: 0.6162
# Epoch 26/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2800 - accuracy: 0.5455
# Epoch 27/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3061 - accuracy: 0.5859
# Epoch 28/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1831 - accuracy: 0.6768
# Epoch 29/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1566 - accuracy: 0.6465
# Epoch 30/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1409 - accuracy: 0.5960
# Epoch 31/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1852 - accuracy: 0.6364
# Epoch 32/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0738 - accuracy: 0.6667
# Epoch 33/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1707 - accuracy: 0.6768
# Epoch 34/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1190 - accuracy: 0.6263
# Epoch 35/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2650 - accuracy: 0.5960
# Epoch 36/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1241 - accuracy: 0.5657
# Epoch 37/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9284 - accuracy: 0.7071
# Epoch 38/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9316 - accuracy: 0.7172
# Epoch 39/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8811 - accuracy: 0.6869
# Epoch 40/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8575 - accuracy: 0.7273
# Epoch 41/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9586 - accuracy: 0.6667
# Epoch 42/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8188 - accuracy: 0.7071
# Epoch 43/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8995 - accuracy: 0.6465
# Epoch 44/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7719 - accuracy: 0.7576
# Epoch 45/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7528 - accuracy: 0.7374
# Epoch 46/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8117 - accuracy: 0.7172
# Epoch 47/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0319 - accuracy: 0.6970
# Epoch 48/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9308 - accuracy: 0.6465
# Epoch 49/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8089 - accuracy: 0.7071
# Epoch 50/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8389 - accuracy: 0.7172
# Epoch 51/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7724 - accuracy: 0.7879
# Epoch 52/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8577 - accuracy: 0.6768
# Epoch 53/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8910 - accuracy: 0.6667
# Epoch 54/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9020 - accuracy: 0.6869
# Epoch 55/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7803 - accuracy: 0.7374
# Epoch 56/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9350 - accuracy: 0.6465
# Epoch 57/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7285 - accuracy: 0.7374
# Epoch 58/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8206 - accuracy: 0.7172
# Epoch 59/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8397 - accuracy: 0.6869
# Epoch 60/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6338 - accuracy: 0.7576
# Epoch 61/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7607 - accuracy: 0.6970
# Epoch 62/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7277 - accuracy: 0.7576
# Epoch 63/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8666 - accuracy: 0.6869
# Epoch 64/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.8643 - accuracy: 0.7374
# Epoch 65/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7440 - accuracy: 0.7374
# Epoch 66/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7757 - accuracy: 0.7172
# Epoch 67/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7748 - accuracy: 0.7475
# Epoch 68/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7228 - accuracy: 0.7576
# Epoch 69/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7515 - accuracy: 0.7475
# Epoch 70/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6846 - accuracy: 0.7879
# Epoch 71/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7248 - accuracy: 0.7576
# Epoch 72/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5823 - accuracy: 0.8283
# Epoch 73/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6006 - accuracy: 0.7778
# Epoch 74/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5439 - accuracy: 0.7879
# Epoch 75/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6296 - accuracy: 0.7576
# Epoch 76/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.8485
# Epoch 77/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7165 - accuracy: 0.7778
# Epoch 78/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7471 - accuracy: 0.7778
# Epoch 79/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6377 - accuracy: 0.7778
# Epoch 80/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6488 - accuracy: 0.7778
# Epoch 81/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6566 - accuracy: 0.8182
# Epoch 82/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5054 - accuracy: 0.8485
# Epoch 83/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7578 - accuracy: 0.7172
# Epoch 84/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5892 - accuracy: 0.7677
# Epoch 85/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.7374
# Epoch 86/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7495 - accuracy: 0.7576
# Epoch 87/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5955 - accuracy: 0.7778
# Epoch 88/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4508 - accuracy: 0.8283
# Epoch 89/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5180 - accuracy: 0.8283
# Epoch 90/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5825 - accuracy: 0.8081
# Epoch 91/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.7855 - accuracy: 0.7071
# Epoch 92/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6047 - accuracy: 0.7576
# Epoch 93/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6111 - accuracy: 0.7475
# Epoch 94/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6552 - accuracy: 0.7677
# Epoch 95/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5237 - accuracy: 0.7980
# Epoch 96/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8485
# Epoch 97/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4922 - accuracy: 0.7980
# Epoch 98/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5305 - accuracy: 0.7677
# Epoch 99/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4537 - accuracy: 0.8182
# Epoch 100/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.7677
# Epoch 101/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5160 - accuracy: 0.8182
# Epoch 102/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5807 - accuracy: 0.7879
# Epoch 103/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.7576
# Epoch 104/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6186 - accuracy: 0.7778
# Epoch 105/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.7980
# Epoch 106/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5518 - accuracy: 0.8081
# Epoch 107/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5776 - accuracy: 0.7475
# Epoch 108/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5202 - accuracy: 0.7778
# Epoch 109/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5391 - accuracy: 0.7879
# Epoch 110/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6827 - accuracy: 0.7677
# Epoch 111/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5197 - accuracy: 0.7778
# Epoch 112/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5346 - accuracy: 0.7980
# Epoch 113/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5433 - accuracy: 0.7980
# Epoch 114/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4587 - accuracy: 0.7879
# Epoch 115/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5731 - accuracy: 0.7475
# Epoch 116/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6574 - accuracy: 0.8081
# Epoch 117/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5811 - accuracy: 0.8081
# Epoch 118/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4820 - accuracy: 0.8283
# Epoch 119/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5153 - accuracy: 0.7879
# Epoch 120/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.7778
# Epoch 121/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.8485
# Epoch 122/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4961 - accuracy: 0.8081
# Epoch 123/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5565 - accuracy: 0.8283
# Epoch 124/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.8283
# Epoch 125/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5536 - accuracy: 0.7980
# Epoch 126/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4870 - accuracy: 0.8182
# Epoch 127/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4088 - accuracy: 0.8384
# Epoch 128/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5139 - accuracy: 0.7778
# Epoch 129/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.7778
# Epoch 130/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5578 - accuracy: 0.7677
# Epoch 131/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8384
# Epoch 132/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4822 - accuracy: 0.8182
# Epoch 133/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.7475
# Epoch 134/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5270 - accuracy: 0.8283
# Epoch 135/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4852 - accuracy: 0.7980
# Epoch 136/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5060 - accuracy: 0.8384
# Epoch 137/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4971 - accuracy: 0.7980
# Epoch 138/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5349 - accuracy: 0.7778
# Epoch 139/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6160 - accuracy: 0.7879
# Epoch 140/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5913 - accuracy: 0.7879
# Epoch 141/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4998 - accuracy: 0.7879
# Epoch 142/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5253 - accuracy: 0.7980
# Epoch 143/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.8182
# Epoch 144/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5405 - accuracy: 0.7980
# Epoch 145/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6086 - accuracy: 0.7677
# Epoch 146/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4281 - accuracy: 0.8182
# Epoch 147/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4584 - accuracy: 0.8384
# Epoch 148/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5298 - accuracy: 0.7980
# Epoch 149/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.8283
# Epoch 150/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4220 - accuracy: 0.8182
# Epoch 151/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5331 - accuracy: 0.7980
# Epoch 152/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5044 - accuracy: 0.7778
# Epoch 153/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5525 - accuracy: 0.8384
# Epoch 154/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4887 - accuracy: 0.7980
# Epoch 155/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5826 - accuracy: 0.7677
# Epoch 156/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5020 - accuracy: 0.8081
# Epoch 157/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5604 - accuracy: 0.7778
# Epoch 158/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5048 - accuracy: 0.8384
# Epoch 159/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5220 - accuracy: 0.7778
# Epoch 160/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4349 - accuracy: 0.8081
# Epoch 161/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4875 - accuracy: 0.8081
# Epoch 162/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5302 - accuracy: 0.7879
# Epoch 163/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4945 - accuracy: 0.8485
# Epoch 164/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5001 - accuracy: 0.7980
# Epoch 165/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4953 - accuracy: 0.7879
# Epoch 166/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5825 - accuracy: 0.8182
# Epoch 167/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5538 - accuracy: 0.7879
# Epoch 168/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6183 - accuracy: 0.7576
# Epoch 169/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5129 - accuracy: 0.7879
# Epoch 170/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4649 - accuracy: 0.8081
# Epoch 171/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4571 - accuracy: 0.7980
# Epoch 172/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4256 - accuracy: 0.8182
# Epoch 173/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5177 - accuracy: 0.7879
# Epoch 174/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3738 - accuracy: 0.8384
# Epoch 175/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5588 - accuracy: 0.8081
# Epoch 176/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4364 - accuracy: 0.8182
# Epoch 177/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4654 - accuracy: 0.7879
# Epoch 178/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5460 - accuracy: 0.7677
# Epoch 179/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5233 - accuracy: 0.8081
# Epoch 180/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5362 - accuracy: 0.8081
# Epoch 181/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5441 - accuracy: 0.8081
# Epoch 182/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6363 - accuracy: 0.7778
# Epoch 183/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5324 - accuracy: 0.7879
# Epoch 184/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4636 - accuracy: 0.8081
# Epoch 185/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4466 - accuracy: 0.8081
# Epoch 186/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.8182
# Epoch 187/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4196 - accuracy: 0.8283
# Epoch 188/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4791 - accuracy: 0.8384
# Epoch 189/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4629 - accuracy: 0.8081
# Epoch 190/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3610 - accuracy: 0.8687
# Epoch 191/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4964 - accuracy: 0.8283
# Epoch 192/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5186 - accuracy: 0.7879
# Epoch 193/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4573 - accuracy: 0.8485
# Epoch 194/200
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4724 - accuracy: 0.7980
# Epoch 195/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5514 - accuracy: 0.7879
# Epoch 196/200
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5200 - accuracy: 0.8283
# Epoch 197/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5194 - accuracy: 0.8283
# Epoch 198/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5035 - accuracy: 0.7778
# Epoch 199/200
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.7980
# Epoch 200/200
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5904 - accuracy: 0.7576
# model is created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('/content/drive/MyDrive/Colab Notebooks/intents.json').read())
words = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/words.pkl','rb'))
classes = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/classes.pkl','rb'))
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
import random

import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
intents_file = open('/content/drive/MyDrive/Colab Notebooks/intents.json').read()
intents = json.loads(intents_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)
        
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=172, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [(['hi'], 'greeting'), (['hello'], 'greeting'), (['whats', 'up'], 'greeting'), (['sup'], 'greeting'), (['is', 'anyone', 'there'], 'greeting'), (['whats', 'good'], 'greeting'), (['hey'], 'greeting'), (['bye'], 'goodbye'), (['cya'], 'goodbye'), (['see', 'you', 'later'], 'goodbye'), (['goodbye'], 'goodbye'), (['im', 'leaving'], 'goodbye'), (['have', 'a', 'good', 'day'], 'goodbye'), (['how', 'old', 'are', 'you'], 'age'), (['what', 'is', 'your', 'age'], 'age'), (['thanks'], 'thanks'), (['thank', 'you'], 'thanks'), (['thankyou'], 'thanks'), (['ty'], 'thanks'), (['I', 'owe', 'you', 'one'], 'thanks'), (['whats', 'is', 'your', 'name'], 'name'), (['whats', 'your', 'name'], 'name'), (['whats', 'should', 'I', 'call', 'you'], 'name'), (['how', 'should', 'I', 'address', 'you'], 'name'), (['Yes', 'it', 'does'], 'sky_net_yes'), (['Yeah'], 'sky_net_yes'), (['Haha', 'yep'], 'sky_net_yes'), (['yes'], 'sky_net_yes'), (['Indeed'], 'sky_net_yes'), (['Yup'], 'sky_net_yes'), (['Just', 'like', 'the', 'terminator'], 'sky_net_yes'), (['no'], 'sky_net_no'), (['nah'], 'sky_net_no'), (['not', 'really'], 'sky_net_no'), (['thats', 'scary'], 'sky_net_no'), (['singularity'], 'sky_net_no'), (['how', 'are', 'you'], 'how_are_you'), (['how', 'are', 'you', 'doing'], 'how_are_you'), (['what', 'is', 'going', 'on'], 'how_are_you'), (['I', 'am', 'doing', 'great'], 'doing_great'), (['I', 'am', 'well'], 'doing_great'), (['Im', 'great'], 'doing_great'), (['awesome'], 'doing_great'), (['happy'], 'doing_great'), (['better'], 'doing_great'), (['not', 'great'], 'doing_badly'), (['not', 'well'], 'doing_badly'), (['not', 'good'], 'doing_badly'), (['bad'], 'doing_badly'), (['badly'], 'doing_badly'), (['terrible'], 'doing_badly'), (['horrible'], 'doing_badly'), (['awful'], 'doing_badly'), (['sad'], 'doing_badly'), (['wait', 'you', 'watch', 'Netflix'], 'netflix'), (['how', 'do', 'you', 'watch', 'Netflix'], 'netflix'), (['Netflix'], 'netflix'), (['how', 'can', 'you', 'run'], 'quick_run'), (['how', 'do', 'you', 'run'], 'quick_run'), (['how', 'run'], 'quick_run'), (['why', 'run'], 'quick_run'), (['run'], 'quick_run'), (['you', 'real'], 'real_bot'), (['you', 'human'], 'real_bot'), (['you', 'robot'], 'real_bot'), (['you', 'alive'], 'real_bot'), (['you', 'sentient'], 'real_bot'), (['you', 'conscious'], 'real_bot'), (['tell', 'me', 'joke'], 'joke'), (['got', 'any', 'good', 'jokes'], 'joke'), (['got', 'jokes'], 'joke'), (['can', 'you', 'tell', 'joke'], 'joke'), (['tell', 'joke'], 'joke'), (['haha'], 'good_joke'), (['that', 'was', 'funny'], 'good_joke'), (['very', 'funny'], 'good_joke'), (['good', 'one'], 'good_joke'), (['bad', 'joke'], 'bad_joke'), (['trash', 'joke'], 'bad_joke'), (['terrible'], 'bad_joke'), (['not', 'funny'], 'bad_joke'), (['I', 'hate', 'you'], 'hate'), (['you', 'stupid'], 'hate'), (['you', 'dumb'], 'hate'), (['you', 'mean'], 'hate'), (['you', 'my', 'friend'], 'like'), (['I', 'like', 'you'], 'like'), (['I', 'love', 'you'], 'like'), (['you', 'cool'], 'like'), (['you', 'are', 'chill'], 'like'), (['whats', 'favorite', 'show'], 'favorite_show'), (['favorite', 'tv', 'show'], 'favorite_show'), (['Whats', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'film'], 'favorite_movie'), (['best', 'movie'], 'favorite_movie'), (['your', 'favorite', 'movie'], 'favorite_movie'), (['whats', 'favorite', 'movie'], 'favorite_movie'), (['What', 'think', 'about'], 'your_thoughts'), (['What', 'your', 'thoughts'], 'your_thoughts')]
# 99 documents
# 21 classes ['age', 'bad_joke', 'doing_badly', 'doing_great', 'favorite_movie', 'favorite_show', 'good_joke', 'goodbye', 'greeting', 'hate', 'how_are_you', 'joke', 'like', 'name', 'netflix', 'quick_run', 'real_bot', 'sky_net_no', 'sky_net_yes', 'thanks', 'your_thoughts']
# 113 unique lemmatized words ['a', 'about', 'address', 'age', 'alive', 'am', 'any', 'anyone', 'are', 'awesome', 'awful', 'bad', 'badly', 'best', 'better', 'bye', 'call', 'can', 'chill', 'conscious', 'cool', 'cya', 'day', 'do', 'doe', 'doing', 'dumb', 'favorite', 'film', 'friend', 'funny', 'going', 'good', 'goodbye', 'got', 'great', 'haha', 'happy', 'hate', 'have', 'hello', 'hey', 'hi', 'horrible', 'how', 'human', 'i', 'im', 'indeed', 'is', 'it', 'joke', 'just', 'later', 'leaving', 'like', 'love', 'me', 'mean', 'movie', 'my', 'nah', 'name', 'netflix', 'no', 'not', 'old', 'on', 'one', 'owe', 'real', 'really', 'robot', 'run', 'sad', 'scary', 'see', 'sentient', 'should', 'show', 'singularity', 'stupid', 'sup', 'tell', 'terminator', 'terrible', 'thank', 'thanks', 'thankyou', 'that', 'thats', 'the', 'there', 'think', 'thought', 'trash', 'tv', 'ty', 'up', 'very', 'wa', 'wait', 'watch', 'well', 'what', 'whats', 'why', 'yeah', 'yep', 'yes', 'you', 'your', 'yup']
# Training data created
# Epoch 1/172
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:70: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 20/20 [==============================] - 1s 2ms/step - loss: 3.0669 - accuracy: 0.0505
# Epoch 2/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9887 - accuracy: 0.0606
# Epoch 3/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9637 - accuracy: 0.1010
# Epoch 4/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9191 - accuracy: 0.0808
# Epoch 5/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.8672 - accuracy: 0.1515
# Epoch 6/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.7957 - accuracy: 0.2121
# Epoch 7/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.6924 - accuracy: 0.2424
# Epoch 8/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.5984 - accuracy: 0.2525
# Epoch 9/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.5840 - accuracy: 0.1919
# Epoch 10/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.3612 - accuracy: 0.3939
# Epoch 11/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.4221 - accuracy: 0.2626
# Epoch 12/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.2778 - accuracy: 0.3535
# Epoch 13/172
# 20/20 [==============================] - 0s 2ms/step - loss: 2.2756 - accuracy: 0.3333
# Epoch 14/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9624 - accuracy: 0.4242
# Epoch 15/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.9871 - accuracy: 0.3434
# Epoch 16/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8703 - accuracy: 0.4242
# Epoch 17/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8727 - accuracy: 0.4646
# Epoch 18/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8121 - accuracy: 0.3838
# Epoch 19/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.7341 - accuracy: 0.4242
# Epoch 20/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5133 - accuracy: 0.5253
# Epoch 21/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4328 - accuracy: 0.5758
# Epoch 22/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3872 - accuracy: 0.5455
# Epoch 23/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1963 - accuracy: 0.7071
# Epoch 24/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2092 - accuracy: 0.5758
# Epoch 25/172
# 20/20 [==============================] - 0s 1ms/step - loss: 1.3167 - accuracy: 0.5354
# Epoch 26/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9623 - accuracy: 0.7374
# Epoch 27/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0452 - accuracy: 0.6667
# Epoch 28/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1086 - accuracy: 0.6364
# Epoch 29/172
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0839 - accuracy: 0.6263
# Epoch 30/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9481 - accuracy: 0.7374
# Epoch 31/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8930 - accuracy: 0.7475
# Epoch 32/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7212 - accuracy: 0.7576
# Epoch 33/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6252 - accuracy: 0.8182
# Epoch 34/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7242 - accuracy: 0.7879
# Epoch 35/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6266 - accuracy: 0.8081
# Epoch 36/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7584 - accuracy: 0.8081
# Epoch 37/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6450 - accuracy: 0.8283
# Epoch 38/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6524 - accuracy: 0.8081
# Epoch 39/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5629 - accuracy: 0.8586
# Epoch 40/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6901 - accuracy: 0.7778
# Epoch 41/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4802 - accuracy: 0.8788
# Epoch 42/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.8889
# Epoch 43/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4673 - accuracy: 0.8485
# Epoch 44/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.8586
# Epoch 45/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.8586
# Epoch 46/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3973 - accuracy: 0.8889
# Epoch 47/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3861 - accuracy: 0.8889
# Epoch 48/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4787 - accuracy: 0.8485
# Epoch 49/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3196 - accuracy: 0.9293
# Epoch 50/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.9091
# Epoch 51/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.9192
# Epoch 52/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4329 - accuracy: 0.8384
# Epoch 53/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3422 - accuracy: 0.9192
# Epoch 54/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3211 - accuracy: 0.9091
# Epoch 55/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3634 - accuracy: 0.8990
# Epoch 56/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2678 - accuracy: 0.9495
# Epoch 57/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3203 - accuracy: 0.9192
# Epoch 58/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2828 - accuracy: 0.9394
# Epoch 59/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9394
# Epoch 60/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3328 - accuracy: 0.9394
# Epoch 61/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2647 - accuracy: 0.9293
# Epoch 62/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3016 - accuracy: 0.9192
# Epoch 63/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8788
# Epoch 64/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.9293
# Epoch 65/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2728 - accuracy: 0.9293
# Epoch 66/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.9596
# Epoch 67/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.9091
# Epoch 68/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2125 - accuracy: 0.9293
# Epoch 69/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.9192
# Epoch 70/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2799 - accuracy: 0.9192
# Epoch 71/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2697 - accuracy: 0.9091
# Epoch 72/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1715 - accuracy: 0.9495
# Epoch 73/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2006 - accuracy: 0.9192
# Epoch 74/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2646 - accuracy: 0.9192
# Epoch 75/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.9495
# Epoch 76/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3004 - accuracy: 0.9091
# Epoch 77/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2850 - accuracy: 0.9293
# Epoch 78/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1700 - accuracy: 0.9697
# Epoch 79/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2149 - accuracy: 0.9293
# Epoch 80/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1764 - accuracy: 0.9697
# Epoch 81/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2122 - accuracy: 0.9091
# Epoch 82/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1872 - accuracy: 0.9495
# Epoch 83/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1480 - accuracy: 0.9697
# Epoch 84/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2849 - accuracy: 0.8990
# Epoch 85/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2979 - accuracy: 0.8990
# Epoch 86/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.9394
# Epoch 87/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9697
# Epoch 88/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1754 - accuracy: 0.9495
# Epoch 89/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1715 - accuracy: 0.9697
# Epoch 90/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.9697
# Epoch 91/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9394
# Epoch 92/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1715 - accuracy: 0.9697
# Epoch 93/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2136 - accuracy: 0.9596
# Epoch 94/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1720 - accuracy: 0.9495
# Epoch 95/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1028 - accuracy: 0.9899
# Epoch 96/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1148 - accuracy: 0.9899
# Epoch 97/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.9697
# Epoch 98/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9596
# Epoch 99/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9596
# Epoch 100/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1143 - accuracy: 0.9596
# Epoch 101/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9697
# Epoch 102/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1127 - accuracy: 0.9697
# Epoch 103/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9091
# Epoch 104/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9394
# Epoch 105/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.9697
# Epoch 106/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9596
# Epoch 107/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1649 - accuracy: 0.9495
# Epoch 108/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1773 - accuracy: 0.9394
# Epoch 109/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.9091
# Epoch 110/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1624 - accuracy: 0.9495
# Epoch 111/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1024 - accuracy: 0.9697
# Epoch 112/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1101 - accuracy: 0.9697
# Epoch 113/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9596
# Epoch 114/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9394
# Epoch 115/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1061 - accuracy: 0.9697
# Epoch 116/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.9697
# Epoch 117/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1271 - accuracy: 0.9596
# Epoch 118/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1628 - accuracy: 0.9394
# Epoch 119/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1751 - accuracy: 0.9495
# Epoch 120/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1022 - accuracy: 0.9596
# Epoch 121/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1038 - accuracy: 0.9798
# Epoch 122/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 0.9798
# Epoch 123/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0908 - accuracy: 0.9899
# Epoch 124/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.9798
# Epoch 125/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9798
# Epoch 126/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9596
# Epoch 127/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1717 - accuracy: 0.9495
# Epoch 128/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0902 - accuracy: 0.9697
# Epoch 129/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1061 - accuracy: 0.9697
# Epoch 130/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9899
# Epoch 131/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0543 - accuracy: 0.9899
# Epoch 132/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1346 - accuracy: 0.9495
# Epoch 133/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1372 - accuracy: 0.9697
# Epoch 134/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1356 - accuracy: 0.9495
# Epoch 135/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1218 - accuracy: 0.9596
# Epoch 136/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1622 - accuracy: 0.9394
# Epoch 137/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 0.9798
# Epoch 138/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1279 - accuracy: 0.9495
# Epoch 139/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1034 - accuracy: 0.9798
# Epoch 140/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1033 - accuracy: 0.9596
# Epoch 141/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.9697
# Epoch 142/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9899
# Epoch 143/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1638 - accuracy: 0.9495
# Epoch 144/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1343 - accuracy: 0.9596
# Epoch 145/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1010 - accuracy: 0.9697
# Epoch 146/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1335 - accuracy: 0.9596
# Epoch 147/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0957 - accuracy: 0.9697
# Epoch 148/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9798
# Epoch 149/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9495
# Epoch 150/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9697
# Epoch 151/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1422 - accuracy: 0.9495
# Epoch 152/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 0.9899
# Epoch 153/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 0.9596
# Epoch 154/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0748 - accuracy: 0.9899
# Epoch 155/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1028 - accuracy: 0.9798
# Epoch 156/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9697
# Epoch 157/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9798
# Epoch 158/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0861 - accuracy: 0.9697
# Epoch 159/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1535 - accuracy: 0.9596
# Epoch 160/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1297 - accuracy: 0.9495
# Epoch 161/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9596
# Epoch 162/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 0.9798
# Epoch 163/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9798
# Epoch 164/172
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0938 - accuracy: 0.9697
# Epoch 165/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.9596
# Epoch 166/172
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.9798
# Epoch 167/172
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1011 - accuracy: 0.9697
# Epoch 168/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.9697
# Epoch 169/172
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9293
# Epoch 170/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9798
# Epoch 171/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9495
# Epoch 172/172
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1271 - accuracy: 0.9495
# model created

# %%
msg = list()
text = str()

# %%
# !pip install text2emotion
import text2emotion as te
# Out:
# Requirement already satisfied: text2emotion in /usr/local/lib/python3.7/dist-packages (0.0.5)
# Requirement already satisfied: emoji>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from text2emotion) (1.7.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from text2emotion) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->text2emotion) (1.15.0)

# %%
@anvil.server.callable
def responsed(msg1):
    msg.append(msg1)
    ints = predict_class(msg1)
    res = getResponse(ints, intents)
    return res

# %%
# SONG RECOMMENDATION

# %%
print("Chatbot : Hey there, Wassup ?")
# responded function takes text of user and returns chatbot output
for i in range(5):
    m = input("User : ")
    res = responsed(m)
    print("Chatbot : "+res)
# Out:
# Chatbot : Hey there, Wassup ?
# User : i am in great fear
# Chatbot : Oh thats funny you actually thought I cared. You crack me up.
# User : the fear of snake
# Chatbot : Yep, I like how it sounds. I got it from the Terminator.
# User : what is your name?
# Chatbot : I'm a robot I dont have an age...
# User : i said name?
# Chatbot : Im not named yet, but I was thinking about calling myself Alex. Doesnt that sound nice?
# User : you making me more fearfull
# Chatbot : Oh yes I am very real and very sentient!

# %%
print(msg)
print(len(msg))
# Out:
# ['it is so much of sadness', 'dont try to make me smile, i am in great fear', 'what is your name?', 'i said name?', 'ok alex, i am going to do suicide']
# 5

# %%
stored=dict()
myemotion=te.get_emotion(m)
stored=myemotion
new_value=max(stored,key=stored.get)
ans=new_value

# %%
print(myemotion)
print(stored)
print(ans)
# Out:
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 1.0, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 1.0, 'Fear': 0.0}
# Sad

# %%
API_KEY = '3114f09cd658ea225c2488bf6bfd6f1e'
USER_AGENT = 'Dataquest'

# %%
pip install requests-cache
# Out:
# Requirement already satisfied: requests-cache in /usr/local/lib/python3.7/dist-packages (0.9.4)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.5 in /usr/local/lib/python3.7/dist-packages (from requests-cache) (1.25.11)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache) (21.4.0)
# Requirement already satisfied: requests<3.0,>=2.22 in /usr/local/lib/python3.7/dist-packages (from requests-cache) (2.23.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: cattrs<2.0,>=1.8 in /usr/local/lib/python3.7/dist-packages (from requests-cache) (1.10.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache) (1.4.4)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.7/dist-packages (from cattrs<2.0,>=1.8->requests-cache) (4.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.22->requests-cache) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.22->requests-cache) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.22->requests-cache) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache) (1.15.0)

# %%
import requests
api_key = '3114f09cd658ea225c2488bf6bfd6f1e'
url=f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag=happy&api_key={api_key}&format=json&limit=5"
response = requests.get(url)
payload = response.json()
# for i in range(4):
r=payload['tracks']['track'][0]
# print(r['url'])
print(payload)
# Out:
# {'tracks': {'track': [{'name': 'Pumped Up Kicks', 'duration': '236', 'mbid': '816b3284-5f24-4f3a-9554-750e0bf5d060', 'url': 'https://www.last.fm/music/Foster+the+People/_/Pumped+Up+Kicks', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Foster the People', 'mbid': 'e0e1a584-dd0a-4bd1-88d1-c4c62895039d', 'url': 'https://www.last.fm/music/Foster+the+People'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '1'}}, {'name': "I'm Yours", 'duration': '242', 'mbid': 'a5a2330e-2fff-4601-a715-6e68a8e98fbf', 'url': 'https://www.last.fm/music/Jason+Mraz/_/I%27m+Yours', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Jason Mraz', 'mbid': '82eb8936-7bf6-4577-8320-a2639465206d', 'url': 'https://www.last.fm/music/Jason+Mraz'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '2'}}, {'name': 'Dog Days Are Over', 'duration': '270', 'mbid': '772ea437-45b3-4868-b3c0-b80526ef0fa3', 'url': 'https://www.last.fm/music/Florence+%252B+the+Machine/_/Dog+Days+Are+Over', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Florence + the Machine', 'mbid': '5fee3020-513b-48c2-b1f7-4681b01db0c6', 'url': 'https://www.last.fm/music/Florence+%252B+the+Machine'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '3'}}, {'name': 'A-Punk', 'duration': '136', 'mbid': '047db898-cedf-48a0-afc2-5b686c9b8840', 'url': 'https://www.last.fm/music/Vampire+Weekend/_/A-Punk', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Vampire Weekend', 'mbid': 'af37c51c-0790-4a29-b995-456f98a6b8c9', 'url': 'https://www.last.fm/music/Vampire+Weekend'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '4'}}, {'name': "Friday I'm in Love", 'duration': '214', 'mbid': '8d9104c6-7d8e-460b-8c3d-2d797f79953d', 'url': 'https://www.last.fm/music/The+Cure/_/Friday+I%27m+in+Love', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'The Cure', 'mbid': '69ee3720-a7cb-4402-b48d-a02c366f2bcf', 'url': 'https://www.last.fm/music/The+Cure'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a ...

# %%
 
@anvil.server.callable
def song_emotion():
     len1 = len(msg)
     dic1 = dict()
     stored=dict()
     myemotion=te.get_emotion(m)
     stored=myemotion
     new_value=max(stored,key=stored.get)
     ans=new_value
     emotion=ans
     dic1['emotion'] = emotion
    
     

     import requests
     api_key = '3114f09cd658ea225c2488bf6bfd6f1e'
     emotion=ans
     
     url=f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag={emotion}&api_key={api_key}&format=json&limit=10"
     response = requests.get(url)
     payload = response.json()
     for i in range(10):
         r=payload['tracks']['track'][i]
         dic1[r['name']] = r['url']
     
     return dic1
 del msg[0:]

# %%
# song_emotion function would return dictionary consisting of emotion and recommended songs
ans = song_emotion()

lst = list(ans.keys())
print("Song Recommendations : ")
for i in range(10):
    print("Song_name : "+lst[i])
    print("Song_URL : "+ans[lst[i]])
# Out:
# Song Recommendations :
# Song_name : emotion
# Song_URL : Sad
# Song_name : Creep
# Song_URL : https://www.last.fm/music/Radiohead/_/Creep
# Song_name : The Scientist
# Song_URL : https://www.last.fm/music/Coldplay/_/The+Scientist
# Song_name : Fix You
# Song_URL : https://www.last.fm/music/Coldplay/_/Fix+You
# Song_name : No Surprises
# Song_URL : https://www.last.fm/music/Radiohead/_/No+Surprises
# Song_name : How to Save a Life
# Song_URL : https://www.last.fm/music/The+Fray/_/How+to+Save+a+Life
# Song_name : Someone Like You
# Song_URL : https://www.last.fm/music/Adele/_/Someone+Like+You
# Song_name : I Will Follow You Into The Dark
# Song_URL : https://www.last.fm/music/Death+Cab+for+Cutie/_/I+Will+Follow+You+Into+The+Dark
# Song_name : Fake Plastic Trees
# Song_URL : https://www.last.fm/music/Radiohead/_/Fake+Plastic+Trees
# Song_name : I MISS YOU
# Song_URL : https://www.last.fm/music/blink-182/_/I+MISS+YOU
